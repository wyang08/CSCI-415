# %%
pwd
# Out:
# 'D:\\Data Analysis\\Data Mining'

# %%
import pandas as pd
total_vaccinations = pd.read_csv("country_vaccinations.csv")

# %%
total_vaccinations.columns
# Out:
# Index(['country', 'iso_code', 'date', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated',
#        'daily_vaccinations_raw', 'daily_vaccinations',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'daily_vaccinations_per_million',
#        'vaccines', 'source_name', 'source_website'],
#       dtype='object')

# %%
total_vaccinations.count()
# Out:
# country                                2555
# iso_code                               2318
# date                                   2555
# total_vaccinations                     1667
# people_vaccinated                      1355
# people_fully_vaccinated                 805
# daily_vaccinations_raw                 1368
# daily_vaccinations                     2458
# total_vaccinations_per_hundred         1667
# people_vaccinated_per_hundred          1355
# people_fully_vaccinated_per_hundred     805
# daily_vaccinations_per_million         2458
# vaccines                               2555
# source_name                            2555
# source_website                         2555
# dtype: int64

# %%
new_total_vaccinations = total_vaccinations
new_total_vaccinations = total_vaccinations.dropna()

# %%
new_total_vaccinations.count()
# Out:
# country                                613
# iso_code                               613
# date                                   613
# total_vaccinations                     613
# people_vaccinated                      613
# people_fully_vaccinated                613
# daily_vaccinations_raw                 613
# daily_vaccinations                     613
# total_vaccinations_per_hundred         613
# people_vaccinated_per_hundred          613
# people_fully_vaccinated_per_hundred    613
# daily_vaccinations_per_million         613
# vaccines                               613
# source_name                            613
# source_website                         613
# dtype: int64

# %%
from IPython.display import HTML, display
import tabulate

display(HTML(tabulate.tabulate(new_total_vaccinations, tablefmt='html')))
# Out:
# <table>
# <tbody>
# <tr><td style="text-align: right;">  33</td><td>Argentina           </td><td>ARG</td><td>2021-01-21</td><td style="text-align: right;">265724          </td><td style="text-align: right;">249372          </td><td style="text-align: right;"> 16352          </td><td style="text-align: right;"> 17791          </td><td style="text-align: right;"> 11704          </td><td style="text-align: right;"> 0.59</td><td style="text-align: right;"> 0.55</td><td style="text-align: right;"> 0.04</td><td style="text-align: right;">  259</td><td>Sputnik V                                                                         </td><td>Ministry of Health                                         </td><td>http://datos.salud.gob.ar/dataset/vacunas-contra-covid-19-dosis-aplicadas-en-la-republica-argentina                                                                                                                </td><td>2021-01-21 00:00:00</td></tr>
# ...
