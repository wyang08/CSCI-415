# %%
import pandas as pd
total = pd.read_csv("hotel_bookings.csv")

# %%
total.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
pd.set_option('display.max_rows', None)

# %%
total.head(20)
# Out:
#            hotel  is_canceled  lead_time  arrival_date_year  \
# 0   Resort Hotel            0        342               2015
# 1   Resort Hotel            0        737               2015
# 2   Resort Hotel            0          7               2015
# 3   Resort Hotel            0         13               2015
# 4   Resort Hotel            0         14               2015
# 5   Resort Hotel            0         14               2015
# 6   Resort Hotel            0          0               2015
# 7   Resort Hotel            0          9               2015
# 8   Resort Hotel            1         85               2015
# 9   Resort Hotel            1         75               2015
# 10  Resort Hotel            1         23               2015
# 11  Resort Hotel            0         35               2015
# 12  Resort Hotel            0         68               2015
# 13  Resort Hotel            0         18               2015
# 14  Resort Hotel            0         37               2015
# ...

# %%
total.count()
# Out:
# hotel                             119390
# is_canceled                       119390
# lead_time                         119390
# arrival_date_year                 119390
# arrival_date_month                119390
# arrival_date_week_number          119390
# arrival_date_day_of_month         119390
# stays_in_weekend_nights           119390
# stays_in_week_nights              119390
# adults                            119390
# children                          119386
# babies                            119390
# meal                              119390
# country                           118902
# market_segment                    119390
# distribution_channel              119390
# is_repeated_guest                 119390
# previous_cancellations            119390
# previous_bookings_not_canceled    119390
# reserved_room_type                119390
# assigned_room_type                119390
# booking_changes                   119390
# deposit_type                      119390
# ...

# %%
first_clean = total[(total['adults'] > 1)]
# temp = totalData[(totalData['Vehicle Expiration Date'] > 0) & (totalData['Vehicle Expiration Date'] < 88880087)]

# %%
first_clean.count()
# Out:
# hotel                             95960
# is_canceled                       95960
# lead_time                         95960
# arrival_date_year                 95960
# arrival_date_month                95960
# arrival_date_week_number          95960
# arrival_date_day_of_month         95960
# stays_in_weekend_nights           95960
# stays_in_week_nights              95960
# adults                            95960
# children                          95956
# babies                            95960
# meal                              95960
# country                           95774
# market_segment                    95960
# distribution_channel              95960
# is_repeated_guest                 95960
# previous_cancellations            95960
# previous_bookings_not_canceled    95960
# reserved_room_type                95960
# assigned_room_type                95960
# booking_changes                   95960
# deposit_type                      95960
# ...

# %%
# df.drop(
#     index=["todd", "kyle"],
# )
second_clean = first_clean[first_clean.reservation_status != 'Canceled']
second_clean.count()
# Out:
# hotel                             59276
# is_canceled                       59276
# lead_time                         59276
# arrival_date_year                 59276
# arrival_date_month                59276
# arrival_date_week_number          59276
# arrival_date_day_of_month         59276
# stays_in_weekend_nights           59276
# stays_in_week_nights              59276
# adults                            59276
# children                          59276
# babies                            59276
# meal                              59276
# country                           59130
# market_segment                    59276
# distribution_channel              59276
# is_repeated_guest                 59276
# previous_cancellations            59276
# previous_bookings_not_canceled    59276
# reserved_room_type                59276
# assigned_room_type                59276
# booking_changes                   59276
# deposit_type                      59276
# ...

# %%
third_clean = second_clean[second_clean.is_canceled != 1]
third_clean.count()
# Out:
# D:\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
# hotel                             59276
# is_canceled                       59276
# lead_time                         59276
# arrival_date_year                 59276
# arrival_date_month                59276
# arrival_date_week_number          59276
# arrival_date_day_of_month         59276
# stays_in_weekend_nights           59276
# stays_in_week_nights              59276
# adults                            59276
# children                          59276
# babies                            59276
# meal                              59276
# country                           59130
# market_segment                    59276
# distribution_channel              59276
# is_repeated_guest                 59276
# previous_cancellations            59276
# ...
